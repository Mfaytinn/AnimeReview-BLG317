# %%
import pandas as pd

# %%
# script
import pandas as pd

df_user_details = pd.read_csv('/home/arsun/projects/AnimeReview-BLG317/data/archive/users-details-2023.csv')

# %%
df_user_details
# Out:
#          Mal ID    Username  Gender                   Birthday  \
# 0             1       Xinil    Male  1985-03-04T00:00:00+00:00
# 1             3     Aokaado    Male                        NaN
# 2             4     Crystal  Female                        NaN
# 3             9      Arcane     NaN                        NaN
# 4            18         Mad     NaN                        NaN
# ...         ...         ...     ...                        ...
# 731285  1291083      Dolopa     NaN                        NaN
# 731286  1291085  alenrobnik     NaN                        NaN
# 731287  1291087   Oblongata     NaN  1993-01-30T00:00:00+00:00
# 731288  1291091      Etnota     NaN                        NaN
# 731289  1291097  JuunanaSai  Female                        NaN
#
#                     Location                     Joined  Days Watched  \
# 0                 California  2004-11-05T00:00:00+00:00         142.3
# ...

# %%
table_1 = df_user_details[['Mal ID', 'Username']]
table_1["user_id"] = table_1["Mal ID"]

table_1.drop(columns=['Mal ID'], inplace=True)

table_1.to_csv('/home/arsun/projects/AnimeReview-BLG317/data/processed/users.csv', index=False)
# Out:
# /tmp/ipykernel_19149/1072462606.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table_1["user_id"] = table_1["Mal ID"]
# /tmp/ipykernel_19149/1072462606.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table_1.drop(columns=['Mal ID'], inplace=True)

# %%
# table 2 Anime Information
df_anime_information = pd.read_csv('/home/arsun/projects/AnimeReview-BLG317/data/archive/anime-dataset-2023.csv')

df_anime_information = df_anime_information.rename({'Name': 'anime_name',
                                                     'English name': 'english_name',
                                                     "Other name": 'other_name',
                                                    "Synopsis": "synopsis",
                                                    "Type": "type_anime"}, axis='columns')

df_anime_information = df_anime_information[['anime_id', 'anime_name', 'english_name', 'other_name', 'synopsis', 'type_anime']]

df_anime_information.to_csv('/home/arsun/projects/AnimeReview-BLG317/data/processed/anime_information.csv', index=False)

# %%
df_anime_scores = pd.read_csv("/home/arsun/projects/AnimeReview-BLG317/data/archive/users-score-2023.csv")

df_anime_scores.head()
# Out:
#    user_id Username  anime_id             Anime Title  rating
# 0        1    Xinil        21               One Piece       9
# 1        1    Xinil        48             .hack//Sign       7
# 2        1    Xinil       320                  A Kite       5
# 3        1    Xinil        49        Aa! Megami-sama!       8
# 4        1    Xinil       304  Aa! Megami-sama! Movie       8

# %%
df_anime_scores.drop(columns=["Anime Title"], inplace=True)

df_anime_scores.rename(columns={"rating": "score", "Username": "username"}, inplace=True)

df_anime_scores.head()

df_anime_scores.to_csv("/home/arsun/projects/AnimeReview-BLG317/data/processed/anime_scores.csv", index=False)

# %%
df_producers = pd.read_csv("/home/arsun/projects/AnimeReview-BLG317/data/archive/anime-dataset-2023.csv")
df_producers.head()
# Out:
#    anime_id                             Name             English name  \
# 0         1                     Cowboy Bebop             Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2         6                           Trigun                   Trigun
# 3         7               Witch Hunter Robin       Witch Hunter Robin
# 4         8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                          Other name Score  \
# 0                         カウボーイビバップ  8.75
# 1                    カウボーイビバップ 天国の扉  8.38
# 2                             トライガン  8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)  7.25
# 4                            冒険王ビィト  6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
# ...

# %%
df_studios = df_producers["Studios"]
df_studios.to_csv("/home/arsun/projects/AnimeReview-BLG317/data/processed/studios.csv", index=False)
df_studios.head()
# Out:
# 0           Sunrise
# 1             Bones
# 2          Madhouse
# 3           Sunrise
# 4    Toei Animation
# Name: Studios, dtype: object

# %%
df_producers = df_producers["Producers"]
df_producers.to_csv("/home/arsun/projects/AnimeReview-BLG317/data/processed/producers.csv", index=False)
df_producers.head()
# Out:
# 0                                        Bandai Visual
# 1                               Sunrise, Bandai Visual
# 2                                 Victor Entertainment
# 3    Bandai Visual, Dentsu, Victor Entertainment, T...
# 4                                     TV Tokyo, Dentsu
# Name: Producers, dtype: object

# %%
df_anime = pd.read_csv("/home/arsun/projects/AnimeReview-BLG317/data/archive/anime-dataset-2023.csv")

df_anime.head()
df_anime.columns
# Out:
# Index(['anime_id', 'Name', 'English name', 'Other name', 'Score', 'Genres',
#        'Synopsis', 'Type', 'Episodes', 'Aired', 'Premiered', 'Status',
#        'Producers', 'Licensors', 'Studios', 'Source', 'Duration', 'Rating',
#        'Rank', 'Popularity', 'Favorites', 'Scored By', 'Members', 'Image URL'],
#       dtype='object')

# %%
df_anime_production = df_anime[["anime_id", "Licensors"]]

df_anime_production.rename(columns={"Licensors": "licensors"}, inplace=True)

df_anime_production.head()

df_anime_production.to_csv("/home/arsun/projects/AnimeReview-BLG317/data/processed/anime_production.csv")
del df_anime_production
# Out:
# /tmp/ipykernel_19149/2411955272.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_anime_production.rename(columns={"Licensors": "licensors"}, inplace=True)

# %%
df_metadata = df_anime[["anime_id", "Episodes", "Aired", "Premiered", "Source"]]
df_metadata.columns = df_metadata.columns.str.lower()
df_metadata.to_csv("/home/arsun/projects/AnimeReview-BLG317/data/processed/anime_metadata.csv", index=False)
del df_metadata

# %%
# Extract the anime_id and genres columns
df_anime_genres = df_anime[['anime_id', 'Genres']]

# Rename the columns to match the table schema
df_anime_genres.rename(columns={'Genres': 'genres'}, inplace=True)

# Save the dataframe to a CSV file
df_anime_genres.to_csv('/home/arsun/projects/AnimeReview-BLG317/data/processed/anime_genres.csv', index=False)
